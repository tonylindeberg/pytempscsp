# %%
import pytempscsp.tempscsp as tempscsp
import importlib
importlib.reload(tempscsp)
import matplotlib.pyplot as plt

# %%
# Compute the time constants for recursive filters from the standard deviation of the time-causal limit kernel
tempscsp.mufromstddev(1)
# Out:
# (array([6.10314314e-05, 1.83071953e-04, 7.31886218e-04, 2.92115436e-03,
#         1.15845482e-02, 4.48623679e-02, 1.61437828e-01, 5.00000000e-01]),
#  array([0.0078125, 0.015625 , 0.03125  , 0.0625   , 0.125    , 0.25     ,
#         0.5      , 1.       ]))

# %%
# Compute the time constants for recursive filters from range of standard deviations of the time-causal limit kernel
tempscsp.mufromstddevs(1, 4)
# Out:
# (array([6.10314314e-05, 1.83071953e-04, 7.31886218e-04, 2.92115436e-03,
#         1.15845482e-02, 4.48623679e-02, 1.61437828e-01, 5.00000000e-01,
#         1.30277564e+00, 3.00000000e+00]),
#  array([0.0078125, 0.015625 , 0.03125  , 0.0625   , 0.125    , 0.25     ,
#         0.5      , 1.       , 2.       , 4.       ]))

# %%
# Plot the kernel and compute its spatial extent, temporal delay as well as the sum of its filter coefficents
from math import sqrt
import numpy as np
deltafcn = tempscsp.deltafcn1D(40)
smooth1 = tempscsp.limitkernfilt(deltafcn, 1)
print([tempscsp.mean1D(smooth1), sqrt(tempscsp.variance1D(smooth1)),np.sum(smooth1),tempscsp.tempdelayfromstddev(1)])
plt.plot(smooth1)
plt.show
# Out:
# [np.float64(0.7217818879103701), 0.9999999999999999, np.float64(0.9999999999999996), np.float64(0.7217818879103701)]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Plot the kernel and compute its spatial extent, temporal delay as well as the sum of its filter coefficents
from math import sqrt
import numpy as np
deltafcn = tempscsp.deltafcn1D(160)
smooth4 = tempscsp.limitkernfilt(deltafcn, 4)
print([tempscsp.mean1D(smooth4), sqrt(tempscsp.variance1D(smooth4))],np.sum(smooth4),tempscsp.tempdelayfromstddev(4))
plt.plot(smooth4)
plt.show
# Out:
# [np.float64(5.02455714672377), 4.000000000000001] 0.9999999999999998 5.02455714672377
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Plot the kernel and compute its spatial extent, temporal delay as well as the sum of its filter coefficents
from math import sqrt
import numpy as np
deltafcn = tempscsp.deltafcn1D(640)
smooth16 = tempscsp.limitkernfilt(deltafcn, 16)
print([tempscsp.mean1D(smooth16), sqrt(tempscsp.variance1D(smooth16)),np.sum(smooth16),tempscsp.tempdelayfromstddev(16)])
plt.plot(smooth16)
plt.show
# Out:
# [np.float64(24.836110655229884), 16.00000000000001, np.float64(1.0000000000000002), np.float64(24.836110655229884)]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Compute the first-order temporal derivative of the time-causal limit kernel
plt.plot(tempscsp.tempder(smooth16, 'Lt', 16))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Compute the second-order temporal derivative of the time-causal limit kernel
plt.plot(tempscsp.tempder(smooth16, 'Ltt', 16))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Compute the quasi quadrature measure
plt.plot(tempscsp.quasiquad(smooth16, 16))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Test the function for computing temporal scale-space representations over a set of temporal scales
from math import sqrt
deltafcn = tempscsp.deltafcn1D(50)
smooth = tempscsp.limitkernfilt_mult(deltafcn, 1, 16)
smooth
# Out:
# (array([[5.40954783e-01, 2.87034764e-01, 1.11966781e-01, 3.96499967e-02,
#          1.35429638e-02, 4.55979423e-03, 1.52625715e-03, 5.09631866e-04,
#          1.69999545e-04, 5.66835087e-05, 1.88968650e-05, 6.29928334e-06,
#          2.09980675e-06, 6.99941928e-07, 2.33314858e-07, 7.77717418e-08,
#          2.59239310e-08, 8.64131269e-09, 2.88043789e-09, 9.60146010e-10,
#          3.20048676e-10, 1.06682893e-10, 3.55609644e-11, 1.18536548e-11,
#          3.95121828e-12, 1.31707276e-12, 4.39024253e-13, 1.46341418e-13,
#          4.87804726e-14, 1.62601575e-14, 5.42005251e-15, 1.80668417e-15,
#          6.02228057e-16, 2.00742686e-16, 6.69142285e-17, 2.23047428e-17,
#          7.43491428e-18, 2.47830476e-18, 8.26101587e-19, 2.75367196e-19,
#          9.17890652e-20, 3.05963551e-20, 1.01987850e-20, 3.39959501e-21,
#          1.13319834e-21, 3.77732779e-22, 1.25910926e-22, 4.19703087e-23,
#          1.39901029e-23, 4.66336764e-24],
# ...

# %%
# Compute they temporal delays for a range of standard deviations
tempscsp.tempdelaysfromstddevs(1, 16)
# Out:
# array([ 0.72178189,  2.02455753,  5.02455753, 11.47077952, 24.83620414])

# %%
# A test signal consisting of Brownian noise
brown = tempscsp.browniannoisesignal1D(1000000)
plt.plot(brown)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Compute the result of smoothing the Brownian noise signal with the time-causal limit kernel
brownsmooth1024 = tempscsp.limitkernfilt(brown, 1024)
plt.plot(brownsmooth1024)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Compute the result of smoothing the Brownian noise signal with the time-causal limit kernel
brownsmooth4096 = tempscsp.limitkernfilt(brown, 4096)
plt.plot(brownsmooth4096)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Compute the result of smoothing the Brownian noise signal with the time-causal limit kernel
brownsmooth16384 = tempscsp.limitkernfilt(brown, 16384)
plt.plot(brownsmooth16384)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Compute the smoothing parameters for sos filtering as a memory-efficient alternative to explicit cascade
muvec, sigma = tempscsp.mufromstddevs(1, 4, 8)
tempscsp.limitkern_composedsospars_alllayers(muvec)
# Out:
# array([[ 1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00, -1.45519152e-11,  3.25702366e-24],
#        [ 9.99999940e-01,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00, -5.95900860e-08,  5.37899739e-17],
#        [ 9.99756035e-01,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00, -2.43965548e-04,  9.02005842e-10],
#        [ 6.11458708e-01,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00, -3.94202061e-01,  5.66076916e-03],
#        [ 1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          8.45298686e+00, -7.45298686e+00,  0.00000000e+00]])

# %%
# Plot the sos kernel and compute its spatial extent, temporal delay as well as the sum of its filter coefficents
from math import sqrt
import numpy as np
deltafcn = tempscsp.deltafcn1D(40)
smooth1sos = tempscsp.limitkernfilt(deltafcn, 1, method='sosfilt')
print([tempscsp.mean1D(smooth1sos), sqrt(tempscsp.variance1D(smooth1sos)),np.sum(smooth1sos),tempscsp.tempdelayfromstddev(1)])
plt.plot(smooth1sos)
plt.show
# Out:
# [np.float64(0.7217818879103702), 0.9999999999999997, np.float64(0.9999999999999997), np.float64(0.7217818879103701)]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Plot the sos kernel and compute its spatial extent, temporal delay as well as the sum of its filter coefficents
from math import sqrt
import numpy as np
deltafcn = tempscsp.deltafcn1D(160)
smooth4sos = tempscsp.limitkernfilt(deltafcn, 4, method='sosfilt')
print([tempscsp.mean1D(smooth4sos), sqrt(tempscsp.variance1D(smooth4sos)),np.sum(smooth4sos),tempscsp.tempdelayfromstddev(4)])
plt.plot(smooth4sos)
plt.show
# Out:
# [np.float64(5.024557146723759), 3.999999999999992, np.float64(0.9999999999999979), np.float64(5.02455714672377)]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Plot the sos kernel and compute its spatial extent, temporal delay as well as the sum of its filter coefficents
from math import sqrt
import numpy as np
deltafcn = tempscsp.deltafcn1D(640)
smooth16sos = tempscsp.limitkernfilt(deltafcn, 16, method='sosfilt')
print([tempscsp.mean1D(smooth16sos), sqrt(tempscsp.variance1D(smooth16sos)),np.sum(smooth16sos),tempscsp.tempdelayfromstddev(16)])
plt.plot(smooth16sos)
plt.show
# Out:
# [np.float64(24.83611065522974), 15.999999999999854, np.float64(0.9999999999999938), np.float64(24.836110655229884)]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Verify that the sos kernel and the regular kernel have similar shape
plt.plot(smooth1, 'r', label='cascade')
plt.plot(smooth1sos, 'b', label='sos')
plt.legend(loc='best')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Verify that the sos kernel and the regular kernel have similar shape
plt.plot(smooth4, 'r', label='cascade')
plt.plot(smooth4sos, 'b', label='sos')
plt.legend(loc='best')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Verify that the sos kernel and the regular kernel have similar shape
plt.plot(smooth16, 'r', label='cascade')
plt.plot(smooth16sos, 'b', label='sos')
plt.legend(loc='best')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
